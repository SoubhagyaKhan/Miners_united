# %%
def getCount(fileName):

    count = 0

    with open(fileName, "r") as f:
        for line in f:
            if line.startswith("#"):
                count += 1
    
    return count

getCount("./q3_datasets/Mutagenicity/graphs.txt")
# Out:
# 4337

# %%
getCount("./q3_datasets/NCI-H23/graphs.txt")
# Out:
# 40353

# %%
getCount("./query_dataset/muta_final_visible")
# Out:
# 50

# %%
getCount("./query_dataset/nci_final_visible")
# Out:
# 50
